# %% [markdown]
# # Welcome to Your First Jupyter Notebook!
#
# This notebook is part of Lab 1 and is designed to help you practice working with Python, Jupyter Notebooks, Git, and GitHub.
#
# Complete all sections labeled **YOUR TURN**.
#
# > **Privacy note:** This repository may be public. Do not include any information you are uncomfortable sharing publicly. You may use fictional or non-identifying information if you prefer.

# %% [markdown]
# ## Section 1: Introduction to Variables
#
# In Python, variables are used to store information. Run the following cell to see a simple example.

# %%
# This is a comment. Comments help explain your code.

greeting = "Hello, World!"
print(greeting)
# Out:
# Hello, World!

# %% [markdown]
# ## Section 2: Personal Introduction
#
# **YOUR TURN!**
#
# Update the values below. You may use real, fictional, or non-identifying information.

# %%
# TODO: Replace with your preferred name or a fictional name
student_name = "Barrett Tucker"

# TODO: Replace with your favorite programming language
# If this is your first programming course, you can keep "Python"
favorite_language = "Python"

# TODO: Replace with a hobby or interest
favorite_hobby = "biking around jax beach"

# TODO: Replace with the year you started learning programming
year_started_coding = 2016

# Do not change the code below
print(f"Hi! My name is {student_name}.")
print(f"My favorite programming language is {favorite_language}.")
print(f"In my free time, I enjoy {favorite_hobby}.")
print(f"I started learning programming in {year_started_coding}.")
# Out:
# Hi! My name is Barrett Tucker.
# My favorite programming language is Python.
# In my free time, I enjoy biking around jax beach.
# I started learning programming in 2016.

# %% [markdown]
# ## Section 3: Basic Math Operations
#
# Python can perform mathematical operations just like a calculator.
#
# Run the following cell and observe the output.

# %%
# Addition
result_add = 10 + 5
print(f"10 + 5 = {result_add}")

# Subtraction
result_sub = 20 - 8
print(f"20 - 8 = {result_sub}")

# Multiplication
result_mult = 6 * 7
print(f"6 × 7 = {result_mult}")

# Division
result_div = 100 / 4
print(f"100 ÷ 4 = {result_div}")
# Out:
# 10 + 5 = 15
# 20 - 8 = 12
# 6 × 7 = 42
# 100 ÷ 4 = 25.0

# %% [markdown]
# ## Section 4: Create Your Own Calculation
#
# **YOUR TURN!**
#
# Choose any two numbers and perform a calculation using them.
#
# You may use addition (`+`), subtraction (`-`), multiplication (`*`), division (`/`), or another basic mathematical operation.

# %%
# TODO: Choose any two numbers
number_1 = 15
number_2 = 3

# TODO: Change the calculation below if you would like
result = number_1 / number_2

print(f"My calculation result is {result}.")
# Out:
# My calculation result is 5.0.

# %% [markdown]
# ## Section 5: Working with a List
#
# Python lists allow us to store multiple values in one variable.
#
# Run the following example.

# %%
programming_languages = ["Python", "Java", "C++"]

print(programming_languages)
print(f"The first language in the list is {programming_languages[0]}.")
# Out:
# ['Python', 'Java', 'C++']
# The first language in the list is Python.

# %% [markdown]
# ### YOUR TURN!
#
# Add one additional programming language to the list below.

# %%
languages = ["Python", "Java"]

# TODO: Add another programming language to this list
languages.append("C++")
languages.append("C#")

print(languages)
# Out:
# ['Python', 'Java', 'C++', 'C#']

# %% [markdown]
# ## Section 6: Final Setup Check
#
# Run the cell below after completing all sections.

# %%
print("MY LAB 1 NOTEBOOK IS COMPLETE!")
# Out:
# MY LAB 1 NOTEBOOK IS COMPLETE!

# %% [markdown]
# # Congratulations!
#
# You have completed the Jupyter Notebook portion of Lab 1.
#
# Before creating your pull request:
#
# 1. Make sure you completed every section labeled **YOUR TURN**.
# 2. Run all cells from top to bottom.
# 3. Confirm that there are no errors.
# 4. Save the notebook.
# 5. Commit your changes to your branch.
# 6. Push your branch to your GitHub fork.
# 7. Create a pull request to the course repository.
#
# > **Important:** Your pull request does **not** need to be merged. Successfully creating the pull request completes the collaboration portion of this lab.
